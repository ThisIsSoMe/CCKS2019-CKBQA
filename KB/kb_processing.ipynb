# %% [markdown]
# ### 观察ccks2019问答知识库的数据形式并进行数据库导入操作

# %% [markdown]
# ### 查看pkubase三元组的信息，分析三元组的基本格式
#
# 格式为：头实体\t关系\t尾实体（空格）.
#
# 实例：<吕云翔>	<国籍>	<中华人民共和国> .
#
# 总行数为：41009142

# %%
# import os
# # 统计数据条数
# count = 0
# for index, line in enumerate(open('./data/pkubase-triples.txt', 'r', encoding='utf-8')):
#     count += 1
# print('总行数：', count)
# with open('./data/pkubase-triples.txt', 'r', encoding='utf-8') as f_read:
#     flag = 0
#     if not (os.path.exists('./data/pkubase-triples_examples.txt')):
#         print('开始写出部分数据。。。')
#         f_write = open('./data/pkubase-triples_examples.txt', 'w', encoding= 'utf-8')
#         flag = 1
#     i = 0
#     for line in f_read:
#         if(i < 1000):
#             print(line)
#             if(flag == 1):
#                 f_write.write(line)
#             i += 1
#         else:
#             break
#     if(flag == 1):
#         f_write.close()
# Out:
# 总行数： 41009142
# <美国奥可斯（香港）国际控股集团>	<公司名称>	"美国奥可斯（香港）国际控股集团有限公司" .
#
# <美国奥可斯（香港）国际控股集团>	<成立时间>	"2007-06-28" .
#
# <美国奥可斯（香港）国际控股集团>	<经营范围>	<培训> .
#
# <美国奥可斯（香港）国际控股集团>	<经营范围>	<影视> .
#
# <美国奥可斯（香港）国际控股集团>	<公司口号>	"品牌立业，质量最好" .
#
# <美国奥可斯（香港）国际控股集团>	<公司编号>	"1145396" .
#
# <青春是我和你一杯酒的深>	<中文名>	"青春是我和你一杯酒的深" .
#
# <青春是我和你一杯酒的深>	<小说进度>	<连载> .
#
# <青春是我和你一杯酒的深>	<连载网站>	<起点_（网站名称）> .
#
# <天使与猎人>	<中文名>	"天使与猎人" .
#
# <天使与猎人>	<小说进度>	<连载> .
#
# <天使与猎人>	<连载网站>	<起点_（网站名称）> .
#
# <霸道王妃>	<中文名>	"霸道王妃" .
#
# <霸道王妃>	<作者>	<涅槃_（佛教用语）> .
#
# <霸道王妃>	<小说进度>	<连载> .
#
# <霸道王妃>	<连载网站>	<小说吧> .
#
# <四库提要宋代总集研究>	<书名>	"《四库提要宋代总集研究》" .
#
# <四库提要宋代总集研究>	<isbn>	"9784762929991" .
#
# <四库提要宋代总集研究>	<页数>	"360" .
#
# <四库提要宋代总集研究>	<定价>	"本体9" .
#
# <四库提要宋代总集研究>	<定价>	"000円＋税" .
#
# <四库提要宋代总集研究>	<出版时间>	"2013-01" .
#
# <四库提要宋代总集研究>	<装帧>	<精装> .
#
# <牛河梁积石冢>	<中文名>	"牛河梁积石冢" .
#
# <牛河梁积石冢>	<发掘时间>	"1983" .
#
# <牛河梁积石冢>	<简介>	"新石器时代" .
#
# <牛河梁积石冢>	<简介>	"红山文化墓地" .
#
# <夏普LCD-40GE220A>	<中文名>	"夏普LCD-40GE220A" .
#
# ...

# %% [markdown]
# ### 查看pkubase-mention2ent.txt文件的数据格式
# 格式为：实体\t知识库中的实体\t名次
# 实例：东风	东风_（汽车品牌）	1
# 总行数：13930117

# %%
# import os
# # 统计数据条数
# # count = 0
# # for index, line in enumerate(open('./data/pkubase-mention2ent.txt', 'r', encoding='utf-8')):
# #     count += 1
# # print('总行数：', count)
# with open('./data/pkubase-mention2ent.txt', 'r', encoding='utf-8') as f_read:
#     flag = 0
#     if not (os.path.exists('./data/pkubase-mention2ent_examples.txt')):
#         print('开始写出部分数据。。。')
#         f_write = open('./data/pkubase-mention2ent_examples.txt', 'w', encoding= 'utf-8')
#         flag = 1
#     i = 0
#     for line in f_read:
#         if(i < 1000):
#             print(line)
#             if(flag == 1):
#                 f_write.write(line)
#             i += 1
#         else:
#             break
#     if(flag == 1):
#         f_write.close()

# %% [markdown]
# ### 查看pkubase-types.txt的数据格式
# 存放的是实体以及所属领域的类型，如<东兴路>	<类型>	<街区路>
# 格式：实体\t<类型>\t类型值(空格).
# 实例：<东兴路>	<类型>	<街区路> .
# 总行数：2518 2627

# %%
# import os
# # count = 0
# # for index, line in enumerate(open('./data/pkubase-types.txt', 'r', encoding='utf-8')):
# #     count += 1
# # print('总行数：', count)
# with open('./data/pkubase-types.txt', 'r', encoding='utf-8') as f_read:
#     flag = 0
#     if not (os.path.exists('./data/pkubase-types_examples.txt')):
#         print('开始写出部分数据。。。')
#         f_write = open('./data/pkubase-types_examples.txt', 'w', encoding= 'utf-8')
#         flag = 1
#     i = 0
#     for line in f_read:
#         if(i < 100):
#             print(line)
#             if(flag == 1):
#                 f_write.write(line)
#             i += 1
#         else:
#             break
#     if(flag == 1):
#         f_write.close()

# %% [markdown]
# ### 连接数据库

# %%
import pymysql
import pandas as pd
import gc
from sqlalchemy import create_engine

read_con = pymysql.connect(host="192.168.126.143",port = 3337, user='root', password='pjzhang', database='ccks_2019',charset='utf8')

save_con = create_engine('mysql+pymysql://root:pjzhang@192.168.126.143:3337/ccks_2019?charset=utf8')
cur = read_con.cursor()

# %% [markdown]
# ### 将pkubase-triples导入数据库

# %%
sql = """CREATE TABLE `pkubase` (
	`id` INT(11) NOT NULL AUTO_INCREMENT,
	`entry` VARCHAR(102) NOT NULL,
	`prop` VARCHAR(46) NOT NULL,
	`value` VARCHAR(320) NOT NULL,
	PRIMARY KEY (`id`),
	INDEX `entry` (`entry`),
	INDEX `prop` (`prop`),
	INDEX `value` (`value`))
COLLATE='utf8_general_ci'
ENGINE=MyISAM
AUTO_INCREMENT= 0
"""
# 创建pkubase
cur.execute(sql)
# Out:
# 0

# %%
import re
from tqdm import tqdm
pattern = re.compile(r'[\t ]+')
count = 0
other = 0
f =  open('../data/官方数据/pkubase-triples.txt','r', encoding = 'utf-8').readlines()
triples = []
i = 1
for line in tqdm(f):
    if line.strip()[-1] == ".": 
        temp = line.strip()[0:-1].strip()
    else:
        print("error!",line)
        continue
    if(temp.count('\t') != 2):
        temp = re.sub(pattern, '\t', temp)
    count += 1
    if(temp.count('\t') != 2):
        print(line, "因为格式不符被丢弃")
        other += 1
        continue
    triples.append(temp.split('\t'))
    if(i % 10000 == 0):
        df = pd.DataFrame(triples, columns=["entry", "prop", "value"])
        df.to_sql(name = "pkubase", con = save_con, if_exists = "append", chunksize = 5000, index = False)
        triples = []
    i += 1
df = pd.DataFrame(triples, columns=["entry", "prop", "value"])
df.to_sql(name = "pkubase", con = save_con, if_exists = "append", chunksize = 5000, index = False)
print('共有数据：', count)
print('被丢弃数据：', other)
# 共有数据： 41009142
# 被丢弃数据： 0
# Out:
#   2%|▏         | 660000/41009142 [01:29<2:07:00, 5294.56it/s]/data/pjzhang/anaconda3/envs/QA/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1300, "Invalid utf8 character string: 'F0A38E'")
#   result = self._query(query)
# /data/pjzhang/anaconda3/envs/QA/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\xA3\\x8E\\xB4\\xE5\\xAD...' for column 'value' at row 380")
#   result = self._query(query)
#   2%|▏         | 740000/41009142 [01:40<1:38:57, 6781.99it/s]/data/pjzhang/anaconda3/envs/QA/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1300, "Invalid utf8 character string: 'F0A099'")
#   result = self._query(query)
# /data/pjzhang/anaconda3/envs/QA/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\xA0\\x99\\xB6\\xE5\\xB1...' for column 'value' at row 4807")
#   result = self._query(query)
# ...

# %% [markdown]
# ### 导入pkubase-types数据

# %%
sql = """CREATE TABLE `pkutype` (
	`id` INT(11) NOT NULL AUTO_INCREMENT,
	`entry` VARCHAR(302) NOT NULL,
	`prop` VARCHAR(8) NOT NULL,
	`value` VARCHAR(39) NOT NULL,
	PRIMARY KEY (`id`),
	INDEX `entry` (`entry`),
	INDEX `prop` (`prop`),
	INDEX `value` (`value`))
COLLATE='utf8_general_ci'
ENGINE=MyISAM
AUTO_INCREMENT= 0
;"""
# 创建 pkutype
cur.execute(sql)
# Out:
# 0

# %%
import re
pattern = re.compile(r'[\t ]+')
count = 0
other = 0
with open('../data/官方数据/pkubase-types.txt','r', encoding = 'utf-8') as f:
    line = True
    while line:
        ans = []
        for i in range(10000):
            line = f.readline()
            if not line:  # 到 EOF，返回空字符串，则终止循环
                break# 逐行读取  
            count += 1
            temp = line.strip()[0:-1].strip()
            if(temp.count('\t') != 2):
                temp = re.sub(pattern, '\t', temp)
            if(temp.count('\t') != 2):
                print(line, "因为格式不符被丢弃")
                other += 1
                continue
            ans.append(temp.split("\t"))
        df  = pd.DataFrame(ans,columns=["entry","prop","value"])
        df.to_sql(name="pkutype",con = save_con ,if_exists="append",chunksize=5000,index=False)
        del df,ans
        gc.collect()
    print('共有数据：', count)
    print('被丢弃数据：', other)
# 共有数据： 25182627
# 被丢弃数据： 0
# Out:
# 共有数据： 25182627
# 被丢弃数据： 0

# %% [markdown]
# ### 导入pkumention2ent数据

# %%
sql = """
CREATE TABLE `pkuorder` (
	`id` INT(11) NOT NULL AUTO_INCREMENT,
	`entry` VARCHAR(100) NOT NULL,
	`prop` VARCHAR(50) NOT NULL,
	`order` INT(3) NOT NULL,
	PRIMARY KEY (`id`),
	INDEX `entry` (`entry`),
	INDEX `prop` (`prop`))
COLLATE='utf8_general_ci'
ENGINE=MyISAM
AUTO_INCREMENT= 0"""

#导入 pkuorder
cur.execute(sql)
# Out:
# 0

# %%
import re
pattern = re.compile(r'[\t ]+')
count = 0
other = 0
with open('../data/官方数据/pkubase-mention2ent.txt','r', encoding = 'utf-8') as f:
    line = True
    while line:
        ans = []
        for i in range(10000):
            line = f.readline()
            if not line:  # 到 EOF，返回空字符串，则终止循环
                break# 逐行读取    
            count += 1
            temp = line.strip()
#             print(temp)
            if(temp.count('\t') != 2):
                temp = re.sub(pattern, '\t', temp)
            if(temp.count('\t') != 2):
                print(line, "因为格式不符被丢弃")
                other += 1
                continue
            ans.append(temp.split("\t"))
#         print('ans', ans)
        df  = pd.DataFrame(ans,columns=["entry","prop","order"])
        df.to_sql(name="pkuorder",con = save_con ,if_exists="append",chunksize=5000,index=False)
        del df,ans
        gc.collect()
    print('共有数据：', count)
    print('被丢弃数据：', other)
# Out:
# /data/pjzhang/anaconda3/envs/QA/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1406, "Data too long for column 'prop' at row 2821")
#   result = self._query(query)
# /data/pjzhang/anaconda3/envs/QA/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1406, "Data too long for column 'prop' at row 4768")
#   result = self._query(query)
# /data/pjzhang/anaconda3/envs/QA/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1406, "Data too long for column 'prop' at row 4594")
#   result = self._query(query)
# /data/pjzhang/anaconda3/envs/QA/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1406, "Data too long for column 'prop' at row 2325")
#   result = self._query(query)
# /data/pjzhang/anaconda3/envs/QA/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1406, "Data too long for column 'prop' at row 4879")
#   result = self._query(query)
# ...
